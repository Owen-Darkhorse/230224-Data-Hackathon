# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/Colab Notebooks/230219-DataHackathon/Notebooks
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Colab Notebooks/230219-DataHackathon/Notebooks

# %%
cyclica = pd.read_csv("../Datasets/sample5000.csv")
cyclica[["feat_DSSP_H", "feat_DSSP_G", "feat_DSSP_I", "feat_DSSP_T",
         "feat_DSSP_E", "feat_DSSP_B", "feat_DSSP_S"]].head(10)
# Out:
#    feat_DSSP_H  feat_DSSP_G  feat_DSSP_I  feat_DSSP_T  feat_DSSP_E  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2         True        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False         True
# 5        False        False        False        False        False
# 6         True        False        False        False        False
# 7        False        False        False        False        False
# 8        False        False        False        False        False
# 9        False        False        False        False        False
#
#    feat_DSSP_B  feat_DSSP_S
# 0        False        False
# 1        False        False
# 2        False        False
# 3        False        False
# 4        False        False
# 5        False         True
# ...

# %%
cyclica[["feat_DSSP_6", "feat_DSSP_7", "feat_DSSP_8", "feat_DSSP_9",
         "feat_DSSP_10", "feat_DSSP_11", "feat_DSSP_12", "feat_DSSP_13"]].head(10)
# Out:
#    feat_DSSP_6  feat_DSSP_7  feat_DSSP_8  feat_DSSP_9  feat_DSSP_10  \
# 0           -2         -0.4            2         -2.4             1
# 1           -5         -2.3            2         -0.3            -6
# 2           -4         -2.4            4         -2.0             1
# 3            1         -0.0            0          0.0             2
# 4           37         -2.8           39         -2.9            -2
# 5           -3         -0.1           -1         -0.2             1
# 6           -4         -0.3            4         -2.2            -3
# 7            1         -0.2           -2         -0.0            -2
# 8           -2         -0.2            0          0.0             1
# 9           -2         -1.9          -22         -0.2             1
#
#    feat_DSSP_11  feat_DSSP_12  feat_DSSP_13
# 0          -0.1             0           0.0
# 1          -0.2            -1          -0.2
# 2          -0.2            -1          -0.2
# ...

# %% [markdown]
# Observations:
# * `feat_DSSP_[letter]` are boolean values show which classification the target protein falls into, while `feat_DSSP_[number]` are all numerical values that relate to backbone secondary sturctures.
# * `feat_DSSP_[number]` are other backbone structural features describing backbone hydrogen, bonding networks. Possibly one column represents one metric of secondary structure.
# * Integer and decimal types alternate between columns of `feat_DSSP_[number]`
#
# Questions:
# * How does `y_Ligand` relate to `feat_DSSP_[letter]`?
# * Why does some `feat_DSSP_[number]` take integers while the others take numbers? How do they relate to `y_Ligand`?
# * What units do the `feat_DSSP_[number]` take? Can I combine them by formula?

# %%
sequence_method_sample.to_csv("../Datasets/230220-sequence_method_sample.csv", index = False)

# %%
structural_method_sample = cyclica.iloc[:, 23:]
structural_method_sample.drop(labels = ["entry", "entry_index"], axis = 1, inplace = True)
structural_method_sample.to_csv("../Datasets/230220-structural_method_sample.csv", index=False)
